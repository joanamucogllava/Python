# %%
#This program will show the graph of a quadratic function.
# Practice Example 

# %pylab inline
x = np.linspace(1, 2, 18)
y = x ** 2 + 1
plt.figure()
plt.plot(x, y, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('This will be the quadratic function figure.')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
